# %% [markdown]
# # Propagación de la pandemia del COVID-19: Entregable de la parte II
# ### Por Emiliano Cabrera, Andrew Dunkerley y Do Hyun Nam
# Profesor: Miguel Eduardo Uribe
#
# Modelación Matemática Fundamental

# %% [markdown]
# ### a)  Separando variables, encuentre la cantidad de personas x(t) que han contráıdo el COVID-19 en el instante de tiempo t utilizando el modelo mateḿatico del inciso(b) de la Parte I.

# %% [markdown]
# Separación de variables:
#
# $\frac {dx}{dt}=kx(n+1-x)$
#
# $\frac {dx}{x(n+1-x)}=k\,dt$
#
# $\int \frac{1}{x(n+1-x)}\,dx=kt+c$
# <br/><br/>
#
#
# Propiedad lineal:
#
# $\int \frac{1}{x(n+1-x)}\,dx$
#
# Descomponemos a fracciones parciales con $n+1$
#
# $\int (\frac{1}{(n+1)(n+1-x)} +\frac{1}{(n+1)x})\,dx$
#
# $\frac{1}{(n+1)} \int \frac{1}{n+1-x}\,dx +\frac{1}{(n+1)}\int \frac{1}{x}\,dx$
# <br/><br/>
#
#
# Para la primera integral:
# $\int \frac{1}{n+1-x}\,dx$
#
# $u=n+1-x --> \frac{du}{dx}=-1 --> dx=-du$
#
# $-\int \frac{1}{u}\,du = -ln(u)$
#
# $=-ln(n+1-x)$
# <br/><br/>
#
#
#
# Para la segunda integral:
# $\int \frac{1}{x}\,dx$
#
# $\int \frac{1}{x}\,dx = ln(x)$
#
# $=ln(x)$
# <br/><br/>
#
#
#
# Insertar las integrales resueltas:
#
# $-\frac{1}{(n+1)} ln(n+1-x) +\frac{1}{(n+1)} ln(x))$
#
# $\frac {ln(x)}{n+1} - \frac{ln(n+1-x)}{n+1}$
#
# $\frac {ln(x)-ln(n+1-x)}{n+1}$
# <br/><br/>
#
#
#
# Regresando a la igualdad:
#
# $\frac {ln(\frac {x}{n+1-x})}{n+1} = kt + c$
# <br/><br/>
#
# Despeje de $x$:
#
# $\frac{x}{n+1-x} = e^{kt(n+1)}e^c$
#
# $x=-xe^{kt(n+1)}e^c+ne^{kt(n+1)}e^c+e^{kt(n+1)}e^c$
#
# $x+xe^{kt(n+1)}e^c=+ne^{kt(n+1)}e^c+e^{kt(n+1)}e^c$
#
# $x(1+e^{kt(n+1)}e^c)=ne^{kt(n+1)}e^c+e^{kt(n+1)}e^c$
#
# $x=\frac{ne^{kt(n+1)}e^c+e^{kt(n+1)}e^c}{1+e^{kt(n+1)}e^c}$
#
# $x=\frac{(+n+1)e^{kt(n+1)}e^c}{1+e^{kt(n+1)}e^c}$
#
# $x(t)=\frac{(n+1)e^{kt(n+1)}e^c}{1+e^{kt(n+1)}e^c}$
# <br/><br/>
#
# Considerando a $A = e^c$ como una constante:
#
# $x(t)=\frac{(n+1)Ae^{kt(n+1)}}{1+Ae^{kt(n+1)}}$
# <br/><br/>
#
# Sabiendo que $x(0) = 1$:
#
# $1=\frac{(n+1)Ae^{k(0)(n+1)}}{1+Ae^{k(0)(n+1)}}$
#
# $1=\frac{(n+1)A}{1+A}$
#
# $1+A=(n+1)A$
#
# $\frac{1+A}{A}=n+1$
#
# $\frac{1}{A}+1=n+1$
#
# $\frac{1}{A}=n$
#
# $A = \frac{1}{n}$

# %% [markdown]
# ### b)  Separando variables, encuentre la cantidad de personas x(t) que han contra ́ıdo el COVID-19 en el instante de tiempo t utilizando el modelo de difusion lineal. Explique por que, según este modelo, todos contraeran la enfermedad.

# %% [markdown]
# Separación de variables:
#
# $\frac {dx}{dt}=r(n-x)$
#
# $\frac {dx}{r(n-x)}= t\,dt$
#
# $\frac {1}{r}\int \frac{1}{n-x}\,dx=t$
#
# $\int \frac{1}{n-x}\,dx=rt+c$
# <br/><br/>
#
# Sustitución de $n-x$
#
# $u=n-x --> \frac{du}{dx}=-1 --> dx=-du$
#
# $-\int \frac{1}{u}\,du = ln(u)$
#
# $=-ln(n-x)$
# <br/><br/>
#
# Regresando a la igualdad:
#
# $-ln(n-x) = rt+c$
#
# $n-x = e^{-rt}e^{-c}$
#
# $-x = -n + e^{-rt}e^{-c}$
#
# $x(t) = n - e^{-rt}e^{-c}$
# <br/><br/>
#
# Considerando a $A = e^{-c}$ como una constante:
#
# $x(t) = n - Ae^{-rt}$
# <br/><br/>
#
# Sabiendo que $x(0) = 1$:
#
# $1 = n - Ae^{-r(0)}$
#
# $1 = n - A$
#
# $A = n-1$

# %% [markdown]
# ### c)  Investigue al menos tres municipios en estados del páıs con baja densidad poblacional y aplique los resultados que se obtuvieron en los  incisos a) y b) para predecir la evolucion del COVID-19 en dichos municipios.

# %% [markdown]
# #### Guanajuato, Guanajuato
# ##### Densidad poblacional $= 181.7\frac{personas}{km^2}$ (2015)
# ##### Habitantes $= 171,709$ personas (2010)
# #### <br />Metepec, Edo. de México
# ##### Densidad poblacional $= 80.6\frac{personas}{km^2}$ (2015)
# ##### Habitantes $= 11,429$ personas (2010)
# #### <br />Villa de Cos, Zacatecas
# ##### Densidad poblacional $= 5.3\frac{personas}{km^2}$ (2015)
# ##### Habitantes $= 34,328$ personas (2010)
# <br /> Fuente: https://www.inegi.org.mx/app/indicadores/

# %% [markdown]
# #### Guanajuato:
# $x(0) = 1$
#
# $x(7) = 2$
#
# $x(18) = 7$
#
# $x(39) = 11$
# <br/><br/>
#
# Modelo 1
#
# $x(7)=\frac{(171710)e^{k7(171710)}\frac{1}{171709}}{1+e^{k7(171710)}\frac{1}{171709}}=2$
#
# $k=\frac{ln(\frac{171709}{85854})}{1201970}\approx5.76681\times10^{-7}$
#
# $x(18)=\frac{(171710)e^{k18(171710)}\frac{1}{171709}}{1+e^{k18(171710)}\frac{1}{171709}}=7$
#
# $k=\frac{ln(\frac{171709}{85854})}{3090780}\approx2.24265\times10^{-7}$
#
# $x(39)=\frac{(171710)e^{k39(171710)}\frac{1}{171709}}{1+e^{k39(171710)}\frac{1}{171709}}=11$
#
# $k=\frac{ln(\frac{171709}{85854})}{6696690}\approx1.03507\times10^{-7}$
#
# $k_{average}\approx3.01484\times10^{-7}$
# <br/><br/>
#
# De manera que se puede describir la evolución con el siguiente modelo:
#
# $x(t)=\frac{(171710)e^{t(3.01484\times10^{-7})(171710)}\frac{1}{171709}}{1+e^{t(3.01484\times10^{-7})(171710)}\frac{1}{171709}}$
# <br/><br/>
#
# Modelo 2
#
# $x(7)=171709-(171708)e^{-r(7)}=2$
#
# $r=-\frac{ln(\frac{171707}{171708})}{7}\approx8.3198\times10^{-7}$
#
# $x(18)=171709-(171708)e^{-r(18)}=7$
#
# $r=-\frac{ln(\frac{171707}{171708})}{18}\approx3.23548\times10^{-7}$
#
# $x(39)=171709-(171708)e^{-r(39)}=11$
#
# $r=-\frac{ln(\frac{171707}{171708})}{39}\approx1.4966\times10^{-7}$
#
# $r_{average}\approx4.35063\times10^{-7}$
# <br/><br/>
#
# De manera que se puede describir la evolución con el siguiente modelo:
#
# $x(t)=171709-(171708)e^{-(4.35063\times10^{-7})t}$

# %% [markdown]
# #### Metepec:
# $x(0) = 1$
#
# $x(11) = 7$
#
# $x(27) = 21$
#
# $x(35) = 30$
# <br/><br/>
#
# Modelo 1
#
# $x(11)=\frac{(11430)e^{k11(11430)}\frac{1}{11429}}{1+e^{k11(11430)}\frac{1}{11429}}=7$
#
# $k=\frac{ln(\frac{80003}{11423})}{125730}\approx1.54811\times10^{-5}$
#
# $x(27)=\frac{(11430)e^{k27(11430)}\frac{1}{11429}}{1+e^{k27(11430)}\frac{1}{11429}}=21$
#
# $k=\frac{ln(\frac{80003}{11423})}{308610}\approx6.3071\times10^{-6}$
#
# $x(35)=\frac{(11430)e^{k35(11430)}\frac{1}{11429}}{1+e^{k35(11430)}\frac{1}{11429}}=30$
#
# $k=\frac{ln(\frac{80003}{11423})}{400050}\approx4.86548\times10^{-6}$
#
# $k_{average}\approx8.88456\times10^{-6}$
# <br/><br/>
#
# De manera que se puede describir la evolución con el siguiente modelo:
#
# $x(t)=\frac{(11430)e^{t(8.88456\times10^{-6})(11430)}\frac{1}{11429}}{1+e^{t(8.88456\times10^{-6})(11430)}\frac{1}{11429}}$
# <br/><br/>
#
# Modelo 2
#
# $x(11)=11429-(11428)e^{-r(11)}=7$
#
# $r=-\frac{ln(\frac{5711}{5714})}{11}\approx4.77422\times10^{-5}$
#
# $x(27)=11429-(11428)e^{-r(27)}=21$
#
# $r=-\frac{ln(\frac{5711}{5714})}{27}\approx1.94505\times10^{-5}$
#
# $x(35)=11429-(11428)e^{-r(35)}=30$
#
# $r=-\frac{ln(\frac{5711}{5714})}{35}\approx1.50047\times10^{-5}$
#
# $r_{average}\approx2.73991\times10^{-5}$
# <br/><br/>
#
# De manera que se puede describir la evolución con el siguiente modelo:
#
# $x(t)=11429-(11428)e^{-(2.73991\times10^{-5})t}$

# %% [markdown]
# #### Villa de Cos:
# $x(0) = 1$
#
# $x(6) = 6$
#
# $x(22) = 8$
#
# $x(33) = 12$
# <br/><br/>
#
# Modelo 1
#
# $x(6)=\frac{(34329)e^{k6(34329)}\frac{1}{34328}}{1+e^{k6(34329)}\frac{1}{34328}}=6$
#
# $k=\frac{ln(\frac{68656}{11441})}{205974}\approx8.69967\times10^{-6}$
#
# $x(22)=\frac{(34329)e^{k22(34329)}\frac{1}{34328}}{1+e^{k22(34329)}\frac{1}{34328}}=8$
#
# $k=\frac{ln(\frac{68656}{11441})}{755238}\approx2.37264\times10^{-6}$
#
# $x(33)=\frac{(34329)e^{k33(34329)}\frac{1}{34328}}{1+e^{k33(34329)}\frac{1}{34328}}=12$
#
# $k=\frac{ln(\frac{68656}{11441})}{1132857}\approx1.58176\times10^{-6}$
#
# $k_{average}\approx4.21802\times10^{-6}$
# <br/><br/>
#
# De manera que se puede describir la evolución con el siguiente modelo:
#
# $x(t)=\frac{(34329)e^{t(4.21802\times10^{-6})(34329)}\frac{1}{34328}}{1+e^{t(4.21802\times10^{-6})(34329)}\frac{1}{34328}}$
# <br/><br/>
#
# Modelo 2
#
# $x(6)=34328-(34327)e^{-r(6)}=6$
#
# $r=-\frac{ln(\frac{34322}{34327})}{6}\approx2.42781\times10^{-5}$
#
# $x(22)=34328-(34327)e^{-r(22)}=8$
#
# $r=-\frac{ln(\frac{34322}{34327})}{22}\approx6.6213\times10^{-6}$
#
# $x(33)=34328-(34327)e^{-r(33)}=12$
#
# $r=-\frac{ln(\frac{34322}{34327})}{33}\approx4.4142\times10^{-6}$
#
# $r_{average}\approx1.17712\times10^{-5}$
# <br/><br/>
#
# De manera que se puede describir la evolución con el siguiente modelo:
#
# $x(t)=34328-(34327)e^{-(1.17712\times10^{-5})t}$
# $x\left(t\right)=((171710/171709)\cdot e^{(t\cdot3.0148\cdot10^{-7}\cdot171710)})/(1+((1/171709)\cdot e^{(t*3.01484*(10^{-7})\cdot171710)}))$

# %% [markdown]
# ### d)  Finalmente grafique las respectivas funciones x(t) que arrojo cada modelo para cada municipio y compare dichas gráficas con las gŕaficas oficiales para dichos municipios que proporciona el gobierno. De acuerdo a los resultados obtenidos explique: ¿Cual de los dos modelos resulta mejor para predecir la evolucion del virus?; ¿Seran estos modelos apropiados para modelar el virus COVID-19?.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#G
tg = np.linspace(0,300)
yG1 = ((171710/171709)*np.e**(t*3.0148*10**-7*171710))/(1+((1/171709)*np.e**(t*3.01484*(10**-7)*171710)))
yG2 = (171709) - (171708*np.e**(-1*t*4.35063*10**-7))

# %%
fig , ax= plt.subplots(1,2, figsize= (15,8))
#G1
plt.subplot(1,2,1)
plt.plot(t,yG1, color = 'red')
plt.grid()
plt.ylabel("contagios")
plt.xlabel("días")
plt.title("Guanajuato 1")
#G2
plt.subplot(1,2,2)
plt.plot(t,yG2)
plt.grid()
plt.ylabel("contagios")
plt.xlabel("días")
plt.title("Guanajuato 2")
# Out:
# Text(0.5, 1.0, 'Guanajuato 2')

# %% [markdown]
# Al analizar las gráficas de Guanajuato, se observa que el primer modelo, es el que tiene un mayor rango a los 300 días (que es un aproximado del total de días desde el primer caso en el municipio). Sin embargo, si bien llega a un aproximado de 150000 casos, el modelo es completamente erroneo; ya que llega a aproximadamente los 150000 casos en el dominio establecido. Por otro lado, el segundo modelo es un número mucho más cercano al modelo gubernamental (con un número de casos de 25 aproximadamente) pero sigue siendo una muy mala aproximación. Por lo tanto, niguno de estos dos modelos se podría utilizar para definir los casos de Guanajuato.

# %% [markdown]
# <img src = "GraphxMunicipio/guanajuato.jpg" width = 900px height = 600px>

# %%
#M
tm = np.linspace(0,270)
yM1 = (11430*np.e**(t*8.88456*(10**-6)*11430)*(1/11429))/((1+np.e**(t*8.88456*(10**-6)*11430)*(1/11429)))
yM2 = 11429 - (11428*np.e**(-1*2.73991*10**-5*t))

# %%
fig , ax= plt.subplots(1,2, figsize= (15,8))
#G1
plt.subplot(1,2,1)
plt.plot(tm,yM1)
plt.grid()
plt.ylabel("contagios")
plt.xlabel("días")
plt.title("Metepec 1")
#G2
plt.subplot(1,2,2)
plt.plot(tm,yM2, color = 'red')
plt.grid()
plt.ylabel("contagios")
plt.xlabel("días")
plt.title("Metepec 2")
# Out:
# Text(0.5, 1.0, 'Metepec 2')

# %% [markdown]
# En cuanto a Metepec, las cifras del primer modelo son mucho más razonables pero siguen sin dar resultados aproximados. Alrededor del día 100, el modelo llega a más o menos los 12000 casos para entonces estancarse en ese punto. Esto indicaría que los ya no habría más contagios a partir de este punto (fenómeno que paso de igual manera en el primer modelo de Guanajuato) lo cual es muy improbable ya que la población de metepec es de 214000 habitantes y al menos de que el gobierno imponga medidas estrictas, esto no puede pasar; haciendolo un modelo no ideal. En cuanto al segundo modelo, igualmente que en las gráficas de Guanajuato, el número de casos es despreciable a comparación de las cifras reales; y por lo tanto, es una mala función para representar el fenómeno.

# %% [markdown]
# <img src = "GraphxMunicipio/metepec.jpg" width = 900px height = 600px>

# %%
#VC
tz = np.linspace(0,210)
yVC1 = (34329*np.e**(t*4.21802*10**-6*34329)*(1/34328))/(1+np.e**(t*4.21802*10**-6*34329)*(1/34328))
yVC2 = 34328 - (34327*np.e**(-1*1.17712*10**-5*t))

# %%
fig , ax = plt.subplots(1,2, figsize= (15,8))
#G1
plt.subplot(1,2,1)
plt.plot(tz,yVC1)
plt.grid()
plt.ylabel("contagios")
plt.xlabel("días")
plt.title("Villa Cos 1")
#G2
plt.subplot(1,2,2)
plt.plot(tz,yVC2, color = 'red')
plt.grid()
plt.ylabel("contagios")
plt.xlabel("días")
plt.title("Villa Cos 2")
# Out:
# Text(0.5, 1.0, 'Villa Cos 2')

# %% [markdown]
# Finalmente, el primer sufre un incremento extremo hasta llegar a los 3500 casos, lo cual lo hace inservible para obtener una buena aproximación. Intrigantemente, el segundo modelo logra encontrarse en un rango cercano a las cifras verdaderas al llegar a los 120 casos en 7 meses. Aunque las cifras reales se encuentran por los 210 casos, es la aproximación más cercana hasta ahora y, aunque no sea fiable, es por lo menos cercano.

# %% [markdown]
# <img src = "GraphxMunicipio/villadecos.jpg" width = 900px height = 600px>

# %% [markdown]
# En conclusión, las gráficas gubernamentales se parecen, más que nada, a un modelo lineal. Por estas razones, se determina que el mejor de los dos modelos para predecir el número total de casos de la pandemia es el segundo; ya que este sigue tanto la forma lineal y se aproxima de mejor manera a los resultados reales. Sin embargo, no se recomienda serguir ninguno de estos dos modelos para generar predicciones de la pandemia, ya que en cualquiera de los casos, las presición de los datos es muy mala como para considerarlos resultados aceptables.
